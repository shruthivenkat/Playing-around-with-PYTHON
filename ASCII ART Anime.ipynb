# %%
import os, time
import pandas as pd

# %%
os.system('cls')
#filenames = []
filenames = [r'C:\Users\pc-pc\Desktop\castle1.txt', r'C:\Users\pc-pc\Desktop\castle2.txt']

# %%
frames = []

# %%
for name in filenames:
    with open(name, "r", encoding="utf8") as f:
        frames.append(f.readlines())
for i in range(10):        
    for frame in frames:
#         os.system('cls')
        print("".join(frame))
#         os.system('cls')
        time.sleep(1)
# Out:
#     >>                                                        >>
#      |                     >>            >>                    |
#      *                     |             |                     *
#     / \                    *             *                    / \
#    /___\                 _/ \           / \_                 /___\
#    [   ]                |/   \_________/   \|                [   ]
#    [ I ]                /     \       /     \                [ I ]
#    [   ]_ _ _          /       \     /       \          _ _ _[   ]
#    [   ] U U |        {#########}   {#########}        | U U [   ]
#    [   ]====/          \=======/     \=======/          \====[   ]
#    [   ]    |           |   I |_ _ _ _| I   |           |    [   ]
#    [___]    |_ _ _ _ _ _|     | U U U |     |_ _ _ _ _ _|    [___]
#    \===/  I | U U U U U |     |=======|     | U U U U U | I  \===/
#     \=/     |===========| I   | + W + |   I |===========|     \=/
# ...
